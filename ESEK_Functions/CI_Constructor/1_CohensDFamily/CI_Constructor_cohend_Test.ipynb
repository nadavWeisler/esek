# %%
import CI_Constructor_cohen_d

#######################################
# 1.1 One Sample Z-test Effect Size CI #
#######################################

params = {
    "Cohensd": 0.2667,
    "Sample Size": 25,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_d_one_sample_z_test(params)

# Print the results
print("Results of One Sample Z-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

##############################################
# 1.2 Paired Samples Z-test Effect Size CI ###
##############################################

params = {
    "Cohensd": 0.2667,
    "Number of Pairs": 25,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_d_Paired_samples_z_test(params)

# Print the results
print("Results of paired samples  Z-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


#########################################
# 1.3 Independent Smaples Z-test CI's ###
#########################################

params = {
    "Cohensd": 0.2667,
    "Sample Size 1": 25,
    "Sample Size 2": 25,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_d_independent_samples_z_test(params)

# Print the results
print("Results of Independent samples Z-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


########################################
# 1.4 One Sample t-test Cohen's d CI ###
########################################

params = {
    "Cohensd": 2.255,
    "Sample Size": 8,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_d_one_sample_t_test(params)

# Print the results
print("Results of One Sample t-Test Cohen's d CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


########################################
# 1.5 One Sample t-test Hedges' g CI's #
########################################

params = {
    "Hedges g": 2.255,
    "Sample Size": 8,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.hedges_g_one_sample(params)

# Print the results
print("Results of One Sample t-Test Hedges' g CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()



#############################################
# 1.6 Paired Samples t-test Cohen's dz CI ###
#############################################

params = {
    "Cohensd": 0.2667,
    "Number of Pairs": 25,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_d_Paired_t_test_dz(params)

# Print the results
print("Results of Cohen's dz paired samples t-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()



################################################
# 1.7 Paired Samples t-test Hedges' gz CI ######
################################################

params = {
    "Hedges g": 0.2667,
    "Number of Pairs": 25,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_d_Paired_t_test_gz(params)

# Print the results
print("Results of Hedges' gz paired samples t-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()



##################################################
# 1.8 Paired Samples t-test Cohen's drm CI #######
##################################################

params = {
    "Cohensd": 0.337,
    "Number of Pairs": 8,
    "Confidence Level": 95,
    "Correlation": -0.145

}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_d_Paired_t_test_drm(params)

# Print the results
print("Results of Cohen's drm paired samples t-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()



##################################################
# 1.9 Paired Samples t-test Hedges' grm CI ######
##################################################

params = {
    "Hedges g": 0.337,
    "Number of Pairs": 8,
    "Confidence Level": 95,
    "Correlation": -0.145
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Hedges_grm_Paired_t_test(params)

# Print the results
print("Results of Hedges' grm paired samples t-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()



##################################################
# 1.10 Paired Smaples Cohen's dav CI #############
##################################################

params = {
    "Cohensd": 1.12815215,
    "Number of Pairs": 8,
    "Standard Deviation Group 1": 1.5526475,
    "Standard Deviation Group 2": 1.0606602,
    "Correlation": -0.74819,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_dav_Paired_t_test_dav(params)

# Print the results
print("Results of Cohen's dav paired samples t-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


##################################################
# 1.11 Paired Smaples Hedge's gav CI #############
##################################################

params = {
    "Hedges g": 0.2667,
    "Number of Pairs": 25,
    "Standard Deviation Group 1": 0.9,
    "Standard Deviation Group 2": 1.1,
    "Correlation": -0.74819,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_d_Paired_t_test_gav(params)

# Print the results
print("Results of Hedges' gav paired samples t-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

######################################################
##### 1.12 Indpendent Smaples Cohen's ds #############
######################################################

params = {
    "CoheHedges gnsd": 1.054092553,
    "Sample Size 1": 12,
    "Sample Size 2": 10,
    "Confidence Level": 95
}

# Call the function
results = CI_Constructor_cohen_d.CI_Constructor_Cohens_D.Cohens_ds_independent_samples_t_test(params)

# Print the results
print("Results of Hedges' gs indpednent samples t-Test CI:")
for key, value in results.items():
    print(f"{key}: {value}")

print()
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: package 'sadists' was built under R version 4.2.3
# Results of One Sample Z-Test CI:
# Central Confidence Interval: [-0.1322  0.6656]
#
# Results of paired samples  Z-Test CI:
# Central Confidence Interval: [-0.1322  0.6656]
#
# Results of Independent samples Z-Test CI:
# Central Confidence Interval: [-0.2901  0.8235]
#
# Results of One Sample t-Test Cohen's d CI:
# Cohen's d Pivotal Confidence Interval: [0.89028732 3.58372131]
# Cohen's d  Non_Central Pivotal Confidence Interval: [1.3116 4.8151]
# Cohen's d Central Confidence Interval (True): [0.44975141 4.06024859]
# Cohen's d Central Confidence Interval (Morris): [0.77644204 3.73355796]
# Cohen's d Central Confidence Interval (Hedges): [0.88552494 3.62447506]
# Cohen's d Central Confidence Interval (Hedges-Olkin): [0.95075616 3.55924384]
# Cohen's d Central Confidence Interval (MLE): [0.39730957 4.11269043]
# ...
