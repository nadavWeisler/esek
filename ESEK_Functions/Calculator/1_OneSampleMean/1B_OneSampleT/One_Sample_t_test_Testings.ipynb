# %%
import One_Sample_t_test

# From t-score
params = {
    "t score": 1.1175,
    "Sample Size": 25,
    "Confidence Level": 95.5
}

# Call the function
results = One_Sample_t_test.One_Sample_ttest.one_sample_from_t_score(params)

# Print the results
print("Results of One Sample t-test from t score:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


# From parameters
params = {
    "Population Mean": 29,
    "Mean Sample": 32.76,
    "Standard Deviation Sample": 16.483,
    "Sample Size": 2500,
    "Confidence Level": 95.5
}

# Call the function
results = One_Sample_t_test.One_Sample_ttest.one_sample_from_params(params)

# Print the results
print("Results of One Sample t-test from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

# From Data
params = {
    "column 1": [21, 11, 51, 49, 52, 47, 12, 53, 17, 50, 14, 33, 11, 50, 49, 52, 47, 22, 25, 30, 19, 51, 16, 18, 19],
    "Population's Mean": 29,
    "Confidence Level": 95
}

# Call the function
results = One_Sample_t_test.One_Sample_ttest.one_sample_from_data(params)

# Print the results
print("Results of One Sample t-test from Data:")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of One Sample t-test from t score:
# Cohen's d: 0.2281
# Hedges' g: 0.2209
# t score: 1.1175
# Degrees of Freedom: 24
# p-value: 0.2748
# Standard Error of Cohen's d (True): 0.0449
# Standard Error of Cohen's d (Morris): 0.0448
# Standard Error of Cohen's d (Hedges): 0.0411
# Standard Error of Cohen's d (Hedges_Olkin): 0.041
# Standard Error of Cohen's d (MLE): 0.0445
# Standard Error of Cohen's d (Large N): 0.0403
# Standard Error of Cohen's d (Small N): 0.0438
# Standard Error of Hedges' g (True): 0.0448
# Standard Error of Hedges' g (Morris): 0.0447
# Standard Error of Hedges' g (Hedges): 0.041
# Standard Error of Hedges' g (Hedges_Olkin): 0.041
# Standard Error of Hedges' g (MLE): 0.0444
# Standard Error of Hedges' g (Large N): 0.0402
# Standard Error of Hedges' g (Small N): 0.0437
# Lower Central CI's Cohen's d: 0.1381
# Upper Central CI's Cohen's d: 0.3181
# Lower Central CI's Hedges' g: 0.131
# Upper Central CI's Hedges' g: 0.3108
# Lower Pivotal CI's Cohen's d: -0.1848
# Upper Pivotal CI's Cohen's d: 0.6273
# Lower Pivotal CI's Hedges' g: -0.1789
# Upper Pivotal CI's Hedges' g: 0.6074
# Lower NCP CI's Cohen's d: -0.1779
# Upper NCP CI's Cohen's d: 0.6799
# Lower NCP CI's Hedges' g: -0.1855
# Upper NCP CI's Hedges' g: 0.6716
# Correction Factor: 0.9684
# Statistical Line Cohen's d:  t(24) = 1.117, p = .275, Cohen's d = 0.228, 95.5% CI(Pivotal) [-0.185,0.627]
# Statistical Line Hedges' g:  t(24) = 1.117, p = .275, Hedges' g = 0.221, 95.5% CI(Pivotal) [-0.179,0.607]
#
# Results of One Sample t-test from Parameters:
# Cohen's d: 0.2281
# Hedges' g: 0.228
# t score: 11.4034
# Degrees of Freedom: 2499
# p-value: 0.0
# Standardizer Cohen's d (Sample's Standard Deviation): 16.483
# Standardizer Hedge's g: 16.4879
# Standard Error of the Mean: 0.3297
# Standard Error of Cohen's d (True): 0.0004
# Standard Error of Cohen's d (Morris): 0.0004
# Standard Error of Cohen's d (Hedges): 0.0004
# Standard Error of Cohen's d (Hedges_Olkin): 0.0004
# Standard Error of Cohen's d (MLE): 0.0004
# Standard Error of Cohen's d (Large N): 0.0004
# Standard Error of Cohen's d (Small N): 0.0004
# Standard Error of Hedges' g (True): 0.0004
# Standard Error of Hedges' g (Morris): 0.0004
# Standard Error of Hedges' g (Hedges): 0.0004
# Standard Error of Hedges' g (Hedges_Olkin): 0.0004
# Standard Error of Hedges' g (MLE): 0.0004
# Standard Error of Hedges' g (Large N): 0.0004
# Standard Error of Hedges' g (Small N): 0.0004
# Lower Central CI's Cohen's d: 0.2273
# Upper Central CI's Cohen's d: 0.2289
# Lower Central CI's Hedges' g: 0.2272
# Upper Central CI's Hedges' g: 0.2289
# Lower Pivotal CI's Cohen's d: 0.1874
# Upper Pivotal CI's Cohen's d: 0.2687
# Lower Pivotal CI's Hedges' g: 0.1874
# Upper Pivotal CI's Hedges' g: 0.2686
# Lower NCP CI's Cohen's d: 0.1877
# Upper NCP CI's Cohen's d: 0.269
# Lower NCP CI's Hedges' g: 0.1876
# Upper NCP CI's Hedges' g: 0.2689
# Correction Factor: 0.9997
# Statistical Line Cohen's d:  t(2499) = 11.403, p < .001, Cohen's d = 0.228, 95.5% CI(Pivotal) [0.187,0.269]
# Statistical Line Hedges' g:  t(2499) = 11.403, p < .001, Hedges' g = 0.228, 95.5% CI(Pivotal) [0.187,0.269]
#
# Results of One Sample t-test from Data:
# Cohen's d: 0.2281
# Hedges' g: 0.2209
# t_score: 1.1175
# Degrees of Freedom: 24
# p-value: 0.2748
# Standard Error of Cohen's d (True): 0.0449
# Standard Error of Cohen's d (Morris): 0.0448
# Standard Error of Cohen's d (Hedges): 0.0411
# Standard Error of Cohen's d (Hedges_Olkin): 0.041
# Standard Error of Cohen's d (MLE): 0.0445
# Standard Error of Cohen's d (Large N): 0.0403
# Standard Error of Cohen's d (Small N): 0.0438
# Standard Error of Hedges' g (True): 0.0448
# Standard Error of Hedges' g (Morris): 0.0447
# Standard Error of Hedges' g (Hedges): 0.041
# Standard Error of Hedges' g (Hedges_Olkin): 0.041
# Standard Error of Hedges' g (MLE): 0.0444
# Standard Error of Hedges' g (Large N): 0.0402
# Standard Error of Hedges' g (Small N): 0.0437
# Standard Error of the Mean: 3.3646
# Standardizer Cohen's d (Sample's Standard Deviation): 16.483
# Standardizer Hedge's g: 17.0215
# Sample's Mean: 32.76
# Population's Mean: 29
# Means Difference: 3.76
# Sample Size: 25
# Sample's Standard Deviation: 16.483
# Lower Central CI's Cohen's d: 0.1401
# Upper Central CI's Cohen's d: 0.3161
# Lower NCP CI's Cohen's d: -0.1685
# Upper NCP CI's Cohen's d: 0.6686
# Lower Pivotal CI's Cohen's d: -0.1758
# Upper Pivotal CI's Cohen's d: 0.6182
# Lower Pivotal CI's Hedges' g: -0.1702
# Upper Pivotal CI's Hedges' g: 0.5987
# Lower Central CI's Hedges' g: 0.133
# Upper Central CI's Hedges' g: 0.3088
# Lower NCP CI's Hedges' g: -0.176
# Upper NCP CI's Hedges' g: 0.6603
# Correction Factor: 0.9684
# Statistical Line Cohen's d:  t(24) = 1.118, p = .275, Cohen's d = 0.228, 95% CI(Pivotal) [-0.176,0.618]
# Statistical Line Hedges' g:  t(24) = 1.118, p = .275, Hedges' g = 0.221, 95% CI(Pivotal) [-0.170,0.599]
