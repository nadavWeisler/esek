# %%
import One_Sample_Z_Test

# From Z-Score
params = {
    "Z-score": 0.2667,
    "Sample Size": 25,
    "Confidence Level": 95
}

# Call the function
results = One_Sample_Z_Test.One_Sample_ZTests.one_sample_from_z_score(params)

# Print the results
print("Results of One Sample Z-Test from Z-score:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


# From Parameters
params = {
    "Population Mean": 50,
    "Popoulation Standard Deviation": 15,
    "Sample's Mean": 49.2,
    "Sample Size": 25,
    "Confidence Level": 95
}

# Call the function
results = One_Sample_Z_Test.One_Sample_ZTests.one_sample_from_parameters(params)

# Print the results
print("Results of One Sample Z-Test from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

# From Data
params = {
    "column_1": [45, 48, 51, 49, 52, 47, 50, 53, 48, 50, 46, 51, 48, 50, 49, 52, 47, 50, 45, 53, 49, 51, 46, 52, 48],
    "Population Mean": 50,
    "Popoulation Standard Deviation": 15,
    "Confidence Level": 95.5
}

# Call the function
results = One_Sample_Z_Test.One_Sample_ZTests.one_sample_from_data(params)
print("Results of One Sample Z-Test from Data:")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of One Sample Z-Test from Z-score:
# Cohen's d: 0.0533
# Z-score: 0.2667
# p-value: 0.7897
# Cohen's d CI Lower: -0.3389
# Cohen's d CI Upper: 0.4456
# Standard Error of the Effect Size: 0.2001
# Statistical Line:  z = .267, p = .790, Cohen's d = .053, 95% CI [-0.339,0.446]
#
# Results of One Sample Z-Test from Parameters:
# Cohen's d: 0.0533
# Z-score: 0.2667
# p-value: 0.7897
# Standart Error of the Mean: 3.0
# Cohen's d CI Lower: -0.3389
# Cohen's d CI Upper: 0.4456
# Standrd Error of the Effect Size: 0.2001
# Statistical Line:  z = .267, p = .790, Cohen's d = .053, 95% CI [-0.339,0.446]
#
# Results of One Sample Z-Test from Data:
# Cohen's d: 0.0533
# Z-score: 0.2667
# p-value: 0.789725820928051
# Standart Error of the Mean: 3.0
# Cohen's d CI Lower: -0.3479
# Cohen's d CI Upper: 0.4545
# Standrd Error of the Effect Size: 0.2001
# Sample's Mean: 49.2
# Sample's Standard Deviation: 2.3805
# Difference Between Means: 0.8
# Sample Size: 25
# Statistical Line:  z = .267, p = .790, Cohen's d = .053, 95.5% CI [-0.348,0.455]
