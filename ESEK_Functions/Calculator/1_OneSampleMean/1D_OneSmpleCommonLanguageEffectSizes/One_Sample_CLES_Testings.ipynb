# %%
import One_Sample_CLES

# From t-score
params = {
    "t score": 1.1175,
    "Sample Size": 25,
    "Confidence Level": 95
}

# Call the function
results = One_Sample_CLES.One_Sample_ttest.one_sample_from_t_score(params)

# Print the results
print("Results of One Sample t-test from t score:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


# From Data
params = {
    "Population Mean": 29,
    "Mean Sample": 32.76,
    "Standard Deviation Sample": 16.483,
    "Sample Size": 25,
    "Confidence Level": 95
}

# Call the function
results = One_Sample_CLES.One_Sample_ttest.one_sample_from_params(params)

# Print the results
print("Results of One Sample t-test from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

# From Data
params = {
    "column 1": [21, 11, 51, 49, 52, 47, 12, 53, 17, 50, 14, 33, 11, 50, 49, 52, 47, 22, 25, 30, 19, 51, 16, 18, 19],
    "Population's Mean": 29,
    "Confidence Level": 95
}

# Call the function
results = One_Sample_CLES.One_Sample_ttest.one_sample_from_data(params)
print("Results of One Sample t-test from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

params = {
    "column 1": ([21, 11, 51, 49, 52, 47, 12, 53, 17, 50, 14, 33, 11, 50, 49, 52, 47, 22, 25, 30, 19, 51, 16, 18, 19]), 
    "Population Mean": 29,
    "Confidence Level": 95,
    "Number of Bootstrap Samples": 95,
    "Trimming Level": 0.2
}
results = One_Sample_CLES.One_Sample_ttest.Robust_One_Sample(params)
print("Results of One Sample Robust t-test:")
for key, value in results.items():
    print(f"{key}: {value}")

print()
# Out:
# Results of One Sample t-test from t score:
# Lower Central CI's CLd: 42.5731
# Upper Central CI's CLd: 74.0041
# Lower Central CI's CLg: 42.3048
# Upper Central CI's CLg: 73.7575
# Lower Non-Central CI's CLd: 43.311
# Upper Non-Central CI's CLd: 74.8115
# Lower Non-Central CI's CLg: 43.0142
# Upper Non-Central CI's CLg: 74.5472
# Lower Pivotal CI's CLd: 43.0232
# Upper Pivotal CI's CLd: 73.1787
# Lower Pivotal CI's CLg: 43.2418
# Upper Pivotal CI's CLg: 72.5303
# Statistical Line CLd: t(24) = 1.117, p = .275, CLd = 59.022, 95% CI(pivotal) [43.023,73.179]
# Statistical Line CLg: t(24) = 1.117, p = .275, CLg = 58.741, 95% CI(pivotal) [43.242,72.530]
#
# Results of One Sample t-test from Parameters:
# Mcgraw & Wong, Common Language Effect Size (CLd): 59.0221
# Mcgraw & Wong, Unbiased Common Language Effect Size (CLg): 58.7414
# t-score: 1.1175
# degrees of freedom: 24
# p-value: 0.2748
# Lower Central CI's CLd: 42.5733
# Upper Central CI's CLd: 74.0042
# Lower Central CI's CLg: 42.305
# ...
