# %%
import numpy as np
import Ordinal_By_Ordinal


#From Contingency Table
params = {
    "Contingency Table" : np.array([[1,2,4,6,2,1,2,1,2,1,2,1], [1,2,3,1,1,1,1,1,2,1,1,1]]),
    "Confidence Level": 95.5,
    "Number Of Bootstraps Samples": 1000

}

# Call the function
results = Ordinal_By_Ordinal.OrdinalbyOrdinal.Ordinal_By_Ordinal_from_Contingency_Table(params)

# Print the results
print("Results of Ordinal by Ordinal from Contingency Table:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


#############
# From Data # 
#############

# *Data must be Numeric (Maybe allow a convertion to subjects? idetify the strings and suggest a conversion to numeric)

params = {
    "Variable 1": [1, 2, 3, 4, 5, 5, 4, 3, 2, 1, 1, 1], 
    "Variable 2": [1, 2, 3, 1, 3, 1, 3, 1, 2, 1, 1, 1], 
    "Confidence Level": 95,
    "Number Of Bootstraps Samples": 10
}

results = Ordinal_By_Ordinal.OrdinalbyOrdinal.Ordinal_By_Ordinal_from_Data(params)


# Call the function
print("Results of Ordinal by Ordinal from Data:")
for key, value in results.items():
    print(f"{key}: {value}")

print()
# Out:
# Results of Ordinal by Ordinal from Contingency Table:
# Contingency Table: [[1 2 4 6 2 1 2 1 2 1 2 1]
#  [1 2 3 1 1 1 1 1 2 1 1 1]]
# Skipped Corrleation : Skipped Correlation IQR based: 0.0148871256910315
# Skipped Correlation MAD based: -0.050272327455128545
# Skipped Correlation IQR based p-value: 0.9263951686346028
# Skipped Correlation MAD based p-value: 0.7742692045355116
# Skipped Correlation IQR based CI's: [-0.3073402781073295, 0.3210579884188614]
# Skipped Correlation MAD based CI's: [-0.3608499155186995, 0.3197219230935099]
# Gausian Rank Correlation : Gaussian Rank Correlation: 0.0148871256910315
# Gaussian Rank Correlation p-value: 0.9263951686346028
# Gaussian Rank Correlation CI's: [-0.03823986176009184, 0.06793019015970371]
# Ginni's Gamma: Ginni's Gamma: 0.027380952380952384
# Ginni's Gamma p-value: 0.8322319354870575
# Ginni's Gamma Standard Error: [0.1292530433156187]
# Confidence Interval's Ginni's Gamma: [-0.23172673759841994, 0.28648864236032473]
# Statistical Line Ginni's Gamma: Ginni's λ(39) = .027, p = 0.8322319354870575, 95.5% CI [-.232, .286]
# Shepherd's Pi: Sheperd's Pi: 0.0148871256910315
# Sheperd's Pi p-value: 0.9263951686346028
# Sheperd's Pi CI's: [-0.03823986176009184, 0.06793019015970371]
# Statistical Line Sheperd's Pi: Shepherd's pi(39) = .015, p = .926, 95.5% CI [-.038, .068]
# The Gamma Family Measures: Sommer's Delta Symmetric: [0.01215278 0.13261107 0.13261911]
# Sommer's Delta Variable 1:: [0.00930851 0.1015806  0.1015806 ]
# Sommers Delta Variabl 2: [0.0175     0.19096756 0.19097152]
# Kendall's Tau A: [0.00853659 0.08484414 0.08484414]
# Kendall's Tau B: [0.01276319 0.13927185 0.1392803 ]
# Stuart Tau C: [0.01665675 0.18176944 0.18176944]
# Gamma Correlation: [0.01928375 0.21037199 0.21043694]
# Wilson's e : [0.008871989860583017, 23355.219512195123, 0.09684673365694982]
# Weighted Tau: 0.25219446419179503
# Weighted Tau p-value: nan
# Z-Statistic_tau_a: 0.10061491325388276
# Z-Statistic_tau_b: 0.09163669996454242
# Z-Statistic_tau_c: 0.0916366999645424
# Z-Statistic_sommers_delta_var1: 0.0916366999645424
# Z-Statistic_sommers_delta_var2: 0.09163669996454242
# Z-Statistic_sommers_delta_symmetric: 0.09163669996454243
# Z-Statistic_Gamma: 0.09163669996454242
# Z-Statistic_Wilson: 0.09160856051180157
# p-value_tau_a: 0.4599280788603442
# p-value_tau_b: 0.4634933458778131
# p-value_tau_c: 0.4634933458778131
# p-value_somer_var1: 0.4634933458778131
# p-value_somer_var2: 0.4634933458778131
# p-value_somer_symmetric: 0.4634933458778131
# p-value_gamma: 0.4634933458778131
# p-value_wilson: 0.4635045248744489
# CI_tau_a: [0.007521048928257692, 0.009552121803449626]
# CI_tau_b: [0.01109618132939802, 0.014430192182733528]
# CI_tau_c: [0.014481074250195052, 0.01883242961655093]
# CI_somer_var1: [0.008092648209633605, 0.010524373066962139]
# CI_somer_var2: [0.01521422603613104, 0.019785773963868963]
# CI_somer_symmetric: [0.010565498135801626, 0.01374005741975393]
# CI_gamma: [0.016765712562759792, 0.021801780550187867]
# CI_wilson: [0.007712789098648651, 0.010031190622517382]
# Spearman Correlation: Spearman: 0.0148871256910315
# Spearman p-value: 0.9263951686346028
# Standard Error (Bonett & Wright): 0.026511672706460942
# Standard Error (Fieller): 0.16701717529076243
# Standard Error (Caruso and_Cliff): 0.16018296801944917
# Confidence Intervals (Bonett Wright): (-0.0382, 0.0679)
# Confidence Intervals (Fieller): (-0.3094, 0.3361)
# Confidence Intervals (Caruso and Cliff): (-0.297, 0.3239)
# Confidence Intervals (Woods): (-0.3105, 0.3372)
# Confidence Intervals (Fisher): (-0.3007, 0.3276)
# Ties Corrected Spearman (Oyeka and Nwankwo Chike, 2014) : 0.01480316800143647
# Ties Corrected Spearman p-value (Oyeka and Nwankwo Chike, 2014) : 0.2834772154240759
# Ties Corrected Spearman Standard Error (Oyeka and Nwankwo Chike, 2014) : 0.0265105680000189
# Ties Corrected Spearman CI's(Oyeka and Nwankwo Chike, 2014) : (-0.0383, 0.0678)
# Ties Corrected Spearman (Taylor, 1964): 0.012499999999999956
# Ties Corrected Spearman p-value  (Taylor, 1964): 0.28348935779996726
# Ties Corrected Spearman Standard Error (Taylor, 1964): 0.02648026315789474
# Ties Corrected Spearman CI's (Taylor, 1964): (-0.0406, 0.0655)
# Statistical Line Spearman: r(39) = .015, p = .926, 95.5% CI [-.038, .068]
# Statistical Line Corrected Spearamn (Oyeka et al.): r(39) = .015, p = .283, 95.5% CI [-.038, .068]
# Statistical Line Corrected Spearamn (Taylor.): r(39) = .012, p = .283, 95.5% CI [-.041, .065]
#
# Results of Ordinal by Ordinal from Data:
# Skipped Corrleation : Skipped Correlation IQR based: 0.4365641250653994
# Skipped Correlation MAD based: 0.9999999999999999
# Skipped Correlation IQR based p-value: 0.15591887363798093
# Skipped Correlation MAD based p-value: 2.4944764867995766e-40
# Skipped Correlation IQR based CI's: [-0.30013440228681537, 0.7848267496823915]
# Skipped Correlation MAD based CI's: [0.9999999999999988, 1.0]
# Gausian Rank Correlation : Gaussian Rank Correlation: 0.4365641250653994
# Gaussian Rank Correlation p-value: 0.15591887363798093
# Gaussian Rank Correlation CI's: [0.19993813190024173, 0.6250727202388902]
# Ginni's Gamma: Ginni's Gamma: 0.29166666666666663
# Ginni's Gamma p-value: 0.23935006493219557
# Ginni's Gamma Standard Error: [0.24788669074359648]
# Confidence Interval's Ginni's Gamma: [-0.1941823194376009, 0.7775156527709342]
# Statistical Line Ginni's Gamma: Ginni's λ(10) = .292, p = 0.23935006493219557, 95% CI [-.194, .778]
# Shepherd's Pi: Sheperd's Pi: 0.6320310366962127
# Sheperd's Pi p-value: 0.036953114653586944
# Sheperd's Pi CI's: [0.42861383077857224, 0.7744630798636746]
# Statistical Line Sheperd's Pi: Shepherd's pi(10) = .632, p = .037, 95% CI [.429, .774]
# The Gamma Family Measures: Sommer's Delta Symmetric: [0.41237113 0.23108886 0.23927004]
# Sommer's Delta Variable 1:: [0.35714286 0.20722494 0.20722494]
# Sommers Delta Variabl 2: [0.48780488 0.2565792  0.28303895]
# Kendall's Tau A: [0.3030303  0.23380571 0.23380571]
# Kendall's Tau B: [0.41739194 0.23390247 0.24218326]
# Stuart Tau C: [0.41666667 0.24176243 0.24176243]
# Gamma Correlation: [0.52631579 0.26550925 0.30538413]
# Wilson's e : [0.3389830508474576, 938.6666666666667, 0.25964124956104084]
# Weighted Tau: 0.4882691834341981
# Weighted Tau p-value: nan
# Z-Statistic_tau_a: 1.2960774464760718
# Z-Statistic_tau_b: 1.7234549688642782
# Z-Statistic_tau_c: 1.7234549688642782
# Z-Statistic_sommers_delta_var1: 1.7234549688642782
# Z-Statistic_sommers_delta_var2: 1.7234549688642782
# Z-Statistic_sommers_delta_symmetric: 1.723454968864278
# Z-Statistic_Gamma: 1.723454968864278
# Z-Statistic_Wilson: 1.3055824196677337
# p-value_tau_a: 0.09747440213439551
# p-value_tau_b: 0.042403140899683125
# p-value_tau_c: 0.042403140899683125
# p-value_somer_var1: 0.042403140899683125
# p-value_somer_var2: 0.042403140899683125
# p-value_somer_symmetric: 0.042403140899683125
# p-value_gamma: 0.042403140899683125
# p-value_wilson: 0.09584730102594402
# CI_tau_a: [0.3002464332784595, 0.30581417278214656]
# CI_tau_b: [0.41460691365402147, 0.42017695747566075]
# CI_tau_c: [0.41378805803536906, 0.4195452752979643]
# CI_somer_var1: [0.3546754783160306, 0.3596102359696837]
# CI_somer_var2: [0.48474984965851187, 0.4908599064390491]
# CI_somer_symmetric: [0.40961961309800465, 0.4151226549432324]
# CI_gamma: [0.5231544330568206, 0.5294771458905477]
# CI_wilson: [0.3358915633390648, 0.34207453835585044]
# Spearman Correlation: Spearman: 0.4365641250653993
# Spearman p-value: 0.15591887363798093
# Standard Error (Bonett & Wright): 0.1353646736147444
# Standard Error (Fieller): 0.34318767136623335
# Standard Error (Caruso and_Cliff): 0.32167847159961044
# Confidence Intervals (Bonett Wright): (0.1999, 0.6251)
# Confidence Intervals (Fieller): (-0.2018, 0.8146)
# Confidence Intervals (Caruso and Cliff): (-0.1611, 0.7999)
# Confidence Intervals (Woods): (-0.268, 0.8369)
# Confidence Intervals (Fisher): (-0.1832, 0.808)
# Ties Corrected Spearman (Oyeka and Nwankwo Chike, 2014) : 0.427023151891834
# Ties Corrected Spearman p-value (Oyeka and Nwankwo Chike, 2014) : 0.00019421906490520066
# Ties Corrected Spearman Standard Error (Oyeka and Nwankwo Chike, 2014) : 0.13483461954954634
# Ties Corrected Spearman CI's(Oyeka and Nwankwo Chike, 2014) : (0.1897, 0.6172)
# Ties Corrected Spearman (Taylor, 1964): 0.3776223776223776
# Ties Corrected Spearman p-value  (Taylor, 1964): 0.00027653502144469705
# Ties Corrected Spearman Standard Error (Taylor, 1964): 0.1320901320901321
# Ties Corrected Spearman CI's (Taylor, 1964): (0.1375, 0.5758)
# Statistical Line Spearman: r(10) = .437, p = .156, 95% CI [.2, .625]
# Statistical Line Corrected Spearamn (Oyeka et al.): r(10) = .427, p < .001, 95% CI [.19, .617]
# Statistical Line Corrected Spearamn (Taylor.): r(10) = .378, p < .001, 95% CI [.138, .576]
