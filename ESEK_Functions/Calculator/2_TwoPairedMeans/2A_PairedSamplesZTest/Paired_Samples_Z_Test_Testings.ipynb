# %%
import Paired_Samples_Z_Test

# From Z-Score
params = {
    "Z-score": 0.2667,
    "Number of Pairs": 25,
    "Confidence Level": 95
}

# Call the function
results = Paired_Samples_Z_Test.Two_paired_Samples_Z_Score.two_dependent_samples_from_z_score(params)

# Print the results
print("Results of Two Paired Sample Z-Test from Z-score:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

# From Parameters
params = {
    "Difference in the Population": 50,
    "Standard Deviation of the Difference in the Population": 15,
    "Sample 1 Mean": 49.2,
    "Sample 2 Mean": 49.2,
    "Number of Pairs": 25,
    "Confidence Level": 95
}

# Call the function
results = Paired_Samples_Z_Test.Two_paired_Samples_Z_Score.two_dependent_samples_from_params(params)

# Print the results
print("Results of Two Paired Sample Z-Test from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


# From Data
params = {
    "column_1": [21, 11, 51, 49, 52, 47, 12, 53, 17, 50, 14, 33, 11, 50, 49, 52, 47, 22, 25, 3, 9, 51, 16, 18, 19],
    "column_2": [22, 48, 14, 55, 33, 44, 50, 22, 48, 16, 46, 23, 48, 50, 49, 52, 47, 50, 45, 53, 59, 16, 46, 52, 48],
    "Difference in the Population": 10,
    "Standard Deviation of the Difference in the Population":15,
    "Confidence Level": 95
}

# Call the function
results = Paired_Samples_Z_Test.Two_paired_Samples_Z_Score.two_dependent_samples_from_data(params)
print("Results of One Sample Z-Test from Data:")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of Two Paired Sample Z-Test from Z-score:
# Cohen's d: 0.0533
# Z-score: 0.2667
# p-value: 0.7897
# Cohen's d CI Lower: -0.3389
# Cohen's d CI Upper: 0.4456
# Standard Error of Cohen's d: 0.2001
# Statistical Line:  z = .267, p = .790, Cohen's d = .053, 95% CI [-0.339, 0.446]
#
# Results of Two Paired Sample Z-Test from Parameters:
# Cohen's d: -3.3333
# Z-score: -16.6667
# p-value: 0.0
# Standard Error of the Mean: 3.0
# Cohen's d CI Lower: -4.337
# Cohen's d CI Upper: -2.3297
# Standard Error of Cohen's d: 0.5121
# Statistical Line:  z = -16.667, p < .001, Cohen's d = -3.333, 95% CI [-4.337, -2.33]
#
# Results of One Sample Z-Test from Data:
# Cohen's d: -1.344
# Z-score: -6.72
# p-value: 0.0
# Standard Error of the Mean: 3.0
# Cohen's d CI Lower: -1.8848
# Cohen's d CI Upper: -0.8032
# Standard Error of Cohen's d: 0.2759
# Mean Sample 1: 31.28
# Mean Sample 2: 41.44
# Standard Deviation Sample 1: 17.934
# Standard Deviation Sample 2: 13.8506
# Sample Size 1: 25
# ...
