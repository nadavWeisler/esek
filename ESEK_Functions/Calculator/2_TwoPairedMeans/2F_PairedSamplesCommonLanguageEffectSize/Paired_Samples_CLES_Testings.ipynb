# %%
import Two_Paired_Samples_CLES
import numpy as np

# From t-score
params = {
    "t Score": -1.8609,
    "Number of Pairs": 25,
    "Confidence Level": 95
}

# Call the function
results = Two_Paired_Samples_CLES.Two_Paired_Common_Language_Effect_Sizes.Common_Language_Effect_Sizes_Paird_Samples_from_t_score(params)

# Print the results
#print("Results of Paired Samples t-test from t score:")
#for key, value in results.items():
#    print(f"{key}: {value}")

#print()

# From Parameters
params = {
    "Difference in the Population": 0,
    "Sample Mean 1": 6,
    "Sample Mean 2": 10.6,
    "Standard Deviation Sample 1": 3.16228,
    "Standard Deviation Sample 2": 3.20936,
    "Number of Pairs": 5,
    "Pearson Correlation": -0.591, 
    "Confidence Level": 95
}

# Call the function
results = Two_Paired_Samples_CLES.Two_Paired_Common_Language_Effect_Sizes.Common_Language_Effect_Sizes_Paird_Samples_from_parameters(params)

# Print the results
#print("Results of Paired Samples t-test from Parameters:")
#for key, value in results.items():
#    print(f"{key}: {value}")

#print()

# From Data
params = {
    "Column 1": np.array([12,15,14,16,12]),
    "Column 2": np.array([12,11,12,13,5]),
    "Difference in the Population": 0,
    "Confidence Level": 95,
    "Number of Bootstapping Samples": 1000
}


# Call the function
results = Two_Paired_Samples_CLES.Two_Paired_Common_Language_Effect_Sizes.Common_Language_Effect_Sizes_Paird_Samples_from_data(params)
print("Results of Paired Samples t-test from Data")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of Paired Samples t-test from Data
# Median: 3
# Median 1: 14.0
# Median 2: 12.0
# Mean 1: 13.8
# Mean 2: 10.6
# Standard Deviation 1: 1.7889
# Standard Deviation 2: 3.2094
# Range 1: 12
# Range 2: 5
# Mcgraw & Wong, Common Language Effect Size (CLdz): 89.182
# Mcgraw & Wong, Unbiased Common Language Effect Size (CLgz): 83.8031
# Lower Central CI's CLdz: 21.8342
# Upper Central CI's CLdz: 99.9424
# Lower Central CI's CLgz: 21.5983
# Upper Central CI's CLgz: 99.7098
# Lower Pivotal CI's CLdz: 49.8796
# Upper Pivotal CI's CLdz: 99.1909
# Lower Pivotal CI's CLgz: 49.9039
# Upper Pivotal CI's CLgz: 97.2491
# ---------------------------------------------------------------------------------------------:
#  :
# Non Parametric CLES:
# -------------------------------------------------------------------------------------------:
# Number of Pairs where Group 1 is Larger: 4
# Number of Pairs where Group 2 is Larger: 0
# Number of Ties : 1
# ...
