# %%
import Two_Independent_Samples_Z_test

# From Z-score
params = {
    "Z score": 0.961,
    "Sample Size 1": 19,
    "Sample Size 2": 25,
    "Confidence Level": 95
}

# Call the function
results = Two_Independent_Samples_Z_test.Two_independent_Samples_Z_Score.two_independent_sample_from_z_score(params)

# Print the results
print("Results of Two Independent Samples Z-Test from Z-Score:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


# From Parameters
params = {
    "Difference in the Population": -2,
    "Standard Deviation of the Difference in the Population": 15,
    "Sample Mean 1": 35.0526,
    "Sample Mean 2": 41.44,
    "Standard Deviation Population 1": 15,
    "Standard Deviation Population 2": 15,
    "Sample Size 1": 19,
    "Sample Size 2": 25,
    "Confidence Level": 95
}

# Call the function
results = Two_Independent_Samples_Z_test.Two_independent_Samples_Z_Score.two_independent_samples_from_params(params)

# Print the results
print("Results of Two Independent Samples Z-Test from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


# From Data
params = {
    "column 1": [21, 11, 51, 49, 52, 47, 12, 53, 17, 50, 14, 33, 11, 50, 49, 52, 47, 22, 25],
    "column 2": [22, 48, 14, 55, 33, 44, 50, 22, 48, 16, 46, 23, 48, 50, 49, 52, 47, 50, 45, 53, 59, 16, 46, 52, 48],
    "Difference in the Population": -2,
    "Standard Deviation Population 1":15,
    "Standard Deviation Population 2":15,
    "Confidence Level": 95
}

# Call the function
results = Two_Independent_Samples_Z_test.Two_independent_Samples_Z_Score.two_independent_samples_from_data(params)
print("Results of Two Independent Samples Z-Test from Data:")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of Two Independent Samples Z-Test from Z-Score:
# Cohen's d: 0.2925
# Z score: 0.961
# p-value: 0.3366
# Cohen's d CI Lower: -0.3072
# Cohen's d CI Upper: 0.8921
# Standard Error of Cohen's d: 0.3059
# Statistical Line:  z = .961, p = .337, Cohen's d = .292, 95% CI [-0.307, 0.892]
#
# Results of Two Independent Samples Z-Test from Parameters:
# Cohen's d: 0.2925
# Z score: 0.961
# p-value: 0.3365
# Standard Error of Mean Difference: 4.5653
# Cohen's d CI Lower: -0.3072
# Cohen's d CI Upper: 0.8921
# Standard Error of Cohen's d: 0.3059
# Statistical Line:  z = .961, p = .337, Cohen's d = .292, 95% CI [-0.307, 0.892]
#
# Results of Two Independent Samples Z-Test from Data:
# Cohen's d: 0.2925
# Z-score: 0.961
# p-value: 0.3365
# Standard Error of Mean Difference: 4.5653
# Cohen's d CI Lower: -0.3072
# Cohen's d CI Upper: 0.8921
# Standard Error of Cohen's d: 0.3059
# Mean Sample 1: 35.0526
# Mean Sample 2: 41.44
# Standard Deviation Sample 1: 17.0015
# ...
