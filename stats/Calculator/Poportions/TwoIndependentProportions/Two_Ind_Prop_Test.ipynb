# %%
import numpy as np
from Two_Ind_Proportions import two_ind_samples_proportions  
import warnings

# Suppress specific warnings (RuntimeWarning in this case)
warnings.filterwarnings("ignore", category=RuntimeWarning)


# Two Indoendent Proportions From Parameters

params = {
    "Proportion Sample 1": 0.6,          
    "Proportion Sample 2": 0.5,           
    "Sample Size 1": 50,                  
    "Sample Size 2": 50,                 
    "Difference in the Population": 0,  
    "Confidence Level": 95                 
}

# Call the function and capture the results
results = two_ind_samples_proportions.Two_Ind_Proportions_From_Parameters(params)

# Print the results
for key, value in results.items():
    print(f"{key}: {value}")
    
    
    
params = {
    "Column 1": np.array([1, 1, 0, 1, 1, 0, 0, 1, 1, 0]),  # Replace with your actual column data
    "Column 2": np.array([0, 1, 0, 0, 1, 1, 0, 0, 0, 1]),  # Replace with your actual column data
    "Confidence Level": 95,  # Confidence level in percentage
    "Populations Difference": 0,  # Expected population difference
    "Defined Success Value": 1  # Define success (e.g., 1 for binary data)
}

# Call the function and capture the results
results = two_ind_samples_proportions.Two_Indpendent_Proportions_From_data(params)

# Print the results
for key, value in results.items():
    print(f"{key}: {value}")
    
    
import numpy as np
from Two_Ind_Proportions import two_ind_samples_proportions  
import warnings


# Define input parameters for Two Independent Proportions From Frequencies
params = {
    "Number of Successes Sample 1": 6,  
    "Number of Successes Sample 2": 112,  
    "Sample Size 1": 22,  
    "Sample Size 2": 841,  
    "Populations Difference": 0,  
    "Confidence Level": 95  
}

# Call the function and capture the results
results = two_ind_samples_proportions.Two_Indpendent_Proportions_From_Frequencies(params)

# Print the results
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Table 1 - Descriptive Statistics
# -------------------------------
# Two Independent Proportion From Parameters:
#   Sample 2's Proportion: 0.5
#   Difference Between Proportions: 0.1
#   Number Of Successes 1: 30.0
#   Number Of Successes 2: 25.0
#   Sample 1 Size: 50
#   Sample 2 Size: 50
#   Difference in Population: 0
#                                                                                                                                                          :
#   Table 2 - Inferntial Statistics:
#   ------------------------------:
#   Standard Error (Wald/Wald Corrected): 0.099
#   Z-score (Wald): 1.0102
#   P-value (Wald): 0.1562
#   Z-score (Wald Corrected): 0.8081
#   P-value (Wald Corrected): 0.2095
#   Standard Error (Wald_H0/Wald Corrected_H0): 0.0995
#   Z-score (Wald_H0): 1.005
#   P-value (Wald_H0): 0.1574
#   Z-score (Wald_H0 Corrected): 0.804
#   P-value (Wald_H0 Corrected): 0.2107
#   Standard Error Hauck & Anderson: 0.1
#   Z-score Hauck & Anderson: 0.9
# ...
