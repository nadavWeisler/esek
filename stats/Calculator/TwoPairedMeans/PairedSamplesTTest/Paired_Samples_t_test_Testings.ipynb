# %%
import PairedSamplesT
import numpy as np

# %% [markdown]
# # From t-score

# %%
params = {
    "t Score": 0.629,
    "Number of Pairs": 8,
    "Confidence Level": 95
}

# Call the function
results = PairedSamplesT.Paired_Samples_ttest.paired_samples_from_t_score(params)

# Print the results
print("Results of Paired Samples t-test from t score:")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of Paired Samples t-test from t score:
# Cohen's dz: 0.2224
# Hedges gz: 0.1975
# t-score: 0.629
# Degrees of Freedom: 7
# p-value: 0.5493
# Standardizer Cohen's dz: 0.7071
# Standardizer Hedges' gz: 0.7961
# Lower Central CI's Cohen's dz: -0.6127
# Upper Central CI's Cohen's dz: 1.0575
# Lower Central CI's Hedges' gz: -0.6344
# Upper Central CI's Hedges' gz: 1.0294
# Lower Pivotal CI's Cohen's dz: -0.4874
# Upper Pivotal CI's Cohen's dz: 0.9171
# Lower Pivotal CI's Hedges' gz: -0.4329
# Upper Pivotal CI's Hedges' gz: 0.8146
# Standard Error of Cohen's dz (True): 0.4261
# Standard Error of Cohen's dz (Morris): 0.4229
# Standard Error of Cohen's dz (Hedges): 0.3585
# Standard Error of Cohen's dz (Hedges_Olkin): 0.3579
# Standard Error of Cohen's dz (MLE): 0.6789
# Standard Error of Cohen's dz (Large N): 0.3546
# Standard Error of Cohen's dz (Small N): 0.6876
# Standard Error of Hedges' gz (True): 0.4245
# Standard Error of Hedges' gz (Morris): 0.4219
# ...

# %% [markdown]
# # From Parameters

# %%
params = {
    "Difference in the Population": 0,
    "Sample Mean 1": 2.75,
    "Sample Mean 2": 2.375,
    "Standard Deviation Sample 1": 1.16496,
    "Standard Deviation Sample 2": 1.06066,
    "Number of Pairs": 8,
    "Pearson Correlation": -0.145, 
    "Confidence Level": 95
}

# Call the function
results = PairedSamplesT.Paired_Samples_ttest.paired_samples_from_parameters(params)

# Print the results
print("Results of Paired Samples t-test from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of Paired Samples t-test from Parameters:
# Cohens dz: 0.2225
# Cohens drm: 0.3367
# Cohens dav: 0.3366
# Hedges gz: 0.1976
# Hedges grm: 0.2991
# Hedges gav: 0.299
# t-score: 0.6293
# Degrees of Freedom: 7
# p-value: 0.5491
# Standard Error of the Mean Difference: 0.5959
# Standardizer Cohen's dz: 1.6854
# Standardizer Hedges gz: 1.8975
# Standardizer Cohen's dav: 1.114
# Standardizer Hedges gav: 1.2543
# Standardizer Cohen's drm: 1.1137
# Standardizer Hedges grm: 1.2539
# Standard Error of Cohen's d (True): 0.4261
# Standard Error of Cohen's d (Morris): 0.4229
# Standard Error of Cohen's d (Hedges): 0.3585
# Standard Error of Cohen's d (Hedges_Olkin): 0.3579
# Standard Error of Cohen's d (MLE): 0.6789
# Standard Error of Cohen's d (Large N): 0.3546
# Standard Error of Cohen's d (Small N): 0.6876
# Standard Error of Hedges' g (True): 0.4245
# Standard Error of Hedges' g (Morris): 0.4219
# Standard Error of Hedges' g (Hedges): 0.3575
# ...

# %% [markdown]
# # From Data

# %%
params = {
    "column_1": np.array([1,2,3,1,2,3,4,3]),
    "column_2": np.array([2,1,4,4,4,3,2,2]),
    "Difference in the Population": 0,
    "Confidence Level": 95
}

# Call the function
results = PairedSamplesT.Paired_Samples_ttest.paired_samples_from_data(params)
print("Results of Paired Samples t-test from Data")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of Paired Samples t-test from Data
# Cohens dz: -0.2225
# Cohens drm: -0.3367
# Cohens dav: -0.3366
# Hedges' gz: -0.1977
# Hedges' grm: -0.2991
# Hedges' gav: -0.299
# t-score: -0.6295
# Degrees of Freedom: 7
# p-value: 0.549
# Standard Error of the Mean Difference: 0.5957
# Standardizer Cohen's dz: 1.685
# Standardizer Hedges' gz: 1.8971
# Standardizer Cohen's dav: 1.114
# Standardizer Hedges' gav: 1.2543
# Standardizer Cohen's drm: 1.1137
# Standardizer Hedges' grm: 1.2539
# Standard Error of Cohen's ds (True): 0.4261
# Standard Error of Cohen's ds (Morris): 0.4229
# Standard Error of Cohen's ds (Hedges): 0.3585
# Standard Error of Cohen's ds (Hedges_Olkin): 0.3579
# Standard Error of Cohen's ds (MLE): 0.6789
# Standard Error of Cohen's ds (Large N): 0.3546
# Standard Error of Cohen's ds (Small N): 0.6876
# Standard Error of Hedges' gs (True): 0.4245
# Standard Error of Hedges' gs (Morris): 0.4219
# Standard Error of Hedges' gs (Hedges): 0.3575
# ...
