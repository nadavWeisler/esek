# %%
import Effect_Size_WithControl_Group

# From Parameters
params = {
    "Difference in the Population": 10,
    "Standart Deviation of the Difference in the Population": 15,
    "Sample Mean Experimental Group": 69.7,
    "Sample Mean Control Group": 64.3,
    "Standard Deviation Experimental Group": 2.8,
    "Standard Deviation Control Group": 2.6,
    "Sample Size Experimental Group": 10,
    "Sample Size Control Group": 20,
    "Difference in the Population": 0, 
    "Confidence Level": 95
}


# Call the function
results = Effect_Size_WithControl_Group.Indpendent_Samples_Control_Group.Two_indpendent_samples_with_Control_Group_from_parameters(params)

# Print the results
print("Results of Indpednent Samples t-test with a control group from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

# From Data
params = {
    "column_1": [22, 48, 14, 55, 33, 44, 50, 22, 48, 16, 46, 23, 48, 50, 49, 52, 47, 50, 45, 53, 59, 16, 46, 52, 48],
    "column_2": [21, 11, 51, 49, 52, 47, 12, 53, 17, 50, 14, 33, 11, 50, 49, 52, 47, 22, 25, 3, 9, 51, 16, 18, 19, 46],
    "Difference in the Population": 6,
    "Confidence Level": 95
}

# Call the function
results = Effect_Size_WithControl_Group.Indpendent_Samples_Control_Group.Two_indpendent_samples_with_Control_Group_from_data(params)
print("Results of Indpednent Samples t-test with a control group from Data")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results of Indpednent Samples t-test with a control group from Parameters:
# Glass' Delta: 2.0769
# Unbiased Glass'; Delta: 1.9937
# Standard Error of Glass' Delta: 0.4422
# Standard Error of Glass' Delta Unbiased: 0.4296
# Standardizer Glass' Delta: 2.6659
# Standardizer Glass' Delta Unbiased: 2.7773
# t-score: 5.23
# Degrees of Freedom: 28
# p-value: 0.0
# Standard Error of the Mean Difference: 1.0325
# Difference Between Samples: 5.4
# Difference in the Population: 0
# Lower Pivotal CI's Glass Delta: 1.2799
# Upper Pivotal CI's Glass' Delta: 2.8565
# Lower Pivotal CI's Glass' Delta Unbiased: 1.2286
# Upper Pivotal CI's Glass' Delta Unbiased: 2.742
# Lower Central CI's Glass Delta: 1.2102
# Upper Central CI's Glass Delta: 2.9436
# Lower Central CI's Glass' Delta Unbiased: 1.1516
# Upper Central CI's Glass' Delta Unbiased: 2.8357
# Correction Factor: 0.9599
# Statistical Line Glass' Delta:  t(28) = 5.230, p < .001, Glass' Δ = 1.994,  95% CI(Pivotal) [1.280, 2.857]
# Statistical Line Uniased Glass' Delta:  t(28) = 5.230, p < .001, Unbiased Glass' Δ = 2.077,  95% CI(Pivotal) [1.229, 2.742]
#
# Results of Indpednent Samples t-test with a control group from Data
# Glass' Delta: -1.1259
# Unbiased Glass'; Delta: -1.0902
# Standard Error of Glass' Delta: 0.2733
# Standard Error of Glass' Delta Unbiased: 0.2697
# Standardizer Glass' Delta: 15.9921
# Standardizer Glass' Delta Unbiased: 16.5145
# t-score: -3.4811
# Degrees of Freedom: 49
# p-value: 0.0011
# Standard Error of the Mean Difference: 4.4795
# Difference Between Samples: -9.5938
# Difference in the Population: 6
# Lower Pivotal CI's Glass Delta: -1.6227
# Upper Pivotal CI's Glass' Delta: -0.6147
# Lower Pivotal CI's Glass' Delta Unbiased: -1.5713
# Upper Pivotal CI's Glass' Delta Unbiased: -0.5953
# Lower Central CI's Glass Delta: -1.6615
# Upper Central CI's Glass Delta: -0.5902
# Lower Central CI's Glass' Delta Unbiased: -1.6189
# Upper Central CI's Glass' Delta Unbiased: -0.5615
# Correction Factor: 0.9684
# Statistical Line Glass' Delta:  t(49) = -3.481, p = .001, Glass' Δ = -1.090,  95% CI(Pivotal) [-1.623, -0.615]
# Statistical Line Uniased Glass' Delta:  t(49) = -3.481, p = .001, Unbiased Glass' Δ = -1.126,  95% CI(Pivotal) [-1.571, -0.595]
