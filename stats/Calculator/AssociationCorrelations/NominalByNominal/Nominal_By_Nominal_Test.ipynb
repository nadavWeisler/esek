# %%
import numpy as np
import Nominal_By_Nominal


########################################
#### Nominal by Nominal Association ####
########################################



#####################
# A. From chi-Score #
#####################


params = {
    "Chi Sqaure Score": 20,
    "Sample Size": 25,
    "Degrees of Freedom": 3,
    "Confidence Level": 95
}

# Call the function
results = Nominal_By_Nominal.NominalbyNominal.Nominal_By_Nominal_from_Chi_Score(params)

# Print the results
print("Results of Nominal by Nominal from Chi Score:")
for key, value in results.items():
    print(f"{key}: {value}")

print()


############################
# B.From Contingency Table #
############################

params = {
   # "Contingency Table" : np.array([[549, 212, 54], [93, 124,54], [233, 78, 33],[119, 42, 13], [225, 41, 46], [455, 12, 7], [402, 132, 153]]), # Liebetrau Example
    "Contingency Table" : np.array([[79, 170, 23], [109, 20, 141]]), # Gray & Williams

    "Confidence Level": 95
}

# Call the function
results = Nominal_By_Nominal.NominalbyNominal.Nominal_By_Nominal_from_Contingency_Table(params)

# Print the results
print("Results of Nominal by Nominal from Contingency Table:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

##################
# C. From Data ###
##################

params = {
    "Column 1": np.array(["1", "1", "1", "2", "2", "2"]), 
    "Column 2": np.array(["a", "a", "b", "b", "b", "a"]), 
    "Confidence Level": 95
}

# Call the function
results = Nominal_By_Nominal.NominalbyNominal.Nominal_By_Nominal_from_Data(params)


# Print the results
print("Results of Nominal by Nominal from Data:")
for key, value in results.items():
    print(f"{key}: {value}")

print()
# Out:
# Results of Nominal by Nominal from Chi Score:
# Cohen's w / Phi: 0.8944
# Cramer's V: 0.5164
# Contigency Coefficient: 0.6667
# Chi Square Score: 20
# Degrees of Freedom: 3
# p-value: 0.0002
# Cohen's w CI Lower: 0.439
# Cohen's w CI Upper: 1.2485
# Cramer's V CI Lower: 0.2535
# Cramer's V CI Upper: 0.7208
# Contingency Coefficient CI Lower: 0.402
# Contingency Coefficient CI Upper: 0.7805
# Statistical Line Cohen's w: χ²(3, N = 25) = 20.000, p < .001, Cohen's  w = 0.894, 95% CI(Pivotal) [0.439, 1.249]
# Statistical Line Cramer's V: χ²(3, N = 25) = 20.000, p < .001, Cramer's V = 0.516, 95% CI(Pivotal) [0.253, 0.721]
# Statistical Line Contingency Coefficient: χ²(3, N = 25) = 20.000, p < .001, C = 0.667, 95% CI(Pivotal) [0.402, 0.781]
#
# Results of Nominal by Nominal from Contingency Table:
# Nominal by Nominal Association: Confidence_Level: 0.95
# chi_square_Bias_corrected: 17.9795
# Chi Square: 208.1062
# Degrees of Freedom Chi Square: 2
# p_value Chi Square: 6.461261903100138e-46
# ...
