# %%
import Pearson_Correlations_diff


params = {
    "Correlation Between Variable 1 and Variable 2": 0.6, 
    "Correlation Between Variable 3 and Variable 4": 0.3,
    "Sample Size Correlation r12": 12, 
    "Sample Size Correlation r34": 6, 
    "Confidence Level": 95
}


#Call the function
results = Pearson_Correlations_diff.Differences_Between_Pearson_Correlations.independent_correlations(params)

# Print the results
print("Results for Difference Between Indpednent Correlations")
for key, value in results.items():
    print(f"{key}: {value}")

print()


params = {
    "Correlation Between Variable 1 and Variable 2": 0.6, 
    "Correlation Between Variable 3 and Variable 4": 0.3,
    "Correlation Between Variable 1 and Variable 3": 0.3,
    "Correlation Between Variable 1 and Variable 4": 0.2,
    "Correlation Between Variable 2 and Variable 3": 0.1,
    "Correlation Between Variable 2 and Variable 4": 0.2,
    "Sample Size": 26, 
    "Confidence Level": 95
}


#Call the function
results = Pearson_Correlations_diff.Differences_Between_Pearson_Correlations.dependent_correlations_Non_Overlapped(params)

# Print the results
print("Results for Difference Between Non Overlapped Correlations")
for key, value in results.items():
    print(f"{key}: {value}")

print()


params = {
    "Correlation Between Variable 1 and Variable 2": 0.6, 
    "Correlation Between Variable 1 and Variable 3": 0.3,
    "Correlation Between Variable 2 and Variable 3": 0.3,
    "Sample Size": 26, 
    "Confidence Level": 95
}


#Call the function
results = Pearson_Correlations_diff.Differences_Between_Pearson_Correlations.dependent_correlations_Overlapped(params)

# Print the results
print("Results for Difference Between Overlapped Correlations")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Results for Difference Between Indpednent Correlations
# Fisher Zr_1: 0.5404195002705842
# Fisher Zr_2: 0.2914567944778671
# Difference_Between Correlations: 0.3
# Cohens q: 0.24896270579271707
# Statistic: 0.3734440586890756
# p-value for the difference: 0.3544089866245036
# Standrd Error Fisher: 0.6666666666666666
# Confidence Intervals Fisher: (-0.7848, 0.9147)
# Confidence Intervals Zou: (-0.6252, 1.3127)
# Statistical Line r12: r12(10) = .6, p = .020, 95% CI [-.112, .832]
# Statistical Line r34: r34(4) = .3, p = .282, 95% CI [-.686, .89]
# Statistical Line difference: Z = 0.373, p = .354, 95% CI [-.625, 1.313]
#
# Results for Difference Between Non Overlapped Correlations
# Fisher Zr_1: 0.6931471805599453
# Fisher Zr_2: 0.30951960420311175
# Difference_Between Correlations: 0.3
# Cohens q: 0.38362757635683353
# Statistic_Pearson: 1.4062433976858448
# p_value_Pearson: 0.1596518614850414
# Statistic_Dunn: 1.3324308906508955
# p_value_Dunn: 0.18271863696013113
# ...
