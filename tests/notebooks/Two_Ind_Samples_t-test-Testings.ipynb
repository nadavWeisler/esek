# %%
import Two_Independent_Samples_t_test

# From t-score
params = {
    "t Score": 2.46183,
    "Sample Size 1": 10,
    "Sample Size 2": 12,
    "Confidence Level": 95
}

# Call the function
results = Two_Independent_Samples_t_test.Indpendnent_samples_ttest.two_independent_from_t_score(params)

# Print the results
print("Results of Independent Samples t-test from t score:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

# From Parameters
params = {
    "Difference in the Population": 10,
    "Standart Deviation of the Difference in the Population": 15,
    "Sample Mean 1": 69.7,
    "Sample Mean 2": 64.3,
    "Standard Deviation Sample 1": 2.8,
    "Standard Deviation Sample 2": 2.6,
    "Sample Size 1": 988,
    "Sample Size 2": 1065,
    "Difference in the Population": 0, 
    "Confidence Level": 95
}

# Call the function
results = Two_Independent_Samples_t_test.Indpendnent_samples_ttest.two_independent_from_parameters(params)

# Print the results
print("Results of Indpednent Samples t-test from Parameters:")
for key, value in results.items():
    print(f"{key}: {value}")

print()

# From Data
params = {
    "column_1": [22, 48, 14, 55, 33, 44, 50, 22, 48, 16, 46, 23, 48, 50, 49, 52, 47, 50, 45, 53, 59, 16, 46, 52, 48],
    "column_2": [21, 11, 51, 49, 52, 47, 12, 53, 17, 50, 14, 33, 11, 50, 49, 52, 47, 22, 25, 3, 9, 51, 16, 18, 19, 46],
    "Difference in the Population": 0,
    "Confidence Level": 95
}

# Call the function
results = Two_Independent_Samples_t_test.Indpendnent_samples_ttest.two_independent_from_data(params)
print("Results of Indpednent Samples t-test from Data")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: package 'sadists' was built under R version 4.2.3
# Results of Independent Samples t-test from t score:
# Cohen's ds: 1.0541
# Hedges' gs: 1.014
# Cohen's dpop: 1.1055
# t-score: 2.4618
# Degrees of Freedom: 20
# p-value: 0.023
# Standard Error of Cohen's ds (True): 0.4873
# Standard Error of Cohen's ds (Morris): 0.4823
# Standard Error of Cohen's ds (Hedges): 0.4595
# Standard Error of Cohen's ds (Hedges_Olkin): 0.4567
# Standard Error of Cohen's ds (MLE): 0.7109
# Standard Error of Cohen's ds (Large N): 0.4569
# Standard Error of Cohen's ds (Small N): 0.7107
# Standard Error of Hedges' gs (True): 0.4848
# Standard Error of Hedges' gs (Morris): 0.4801
# Standard Error of Hedges' gs (Hedges): 0.4572
# Standard Error of Hedges' gs (Hedges_Olkin): 0.4546
# Standard Error of Hedges' gs (MLE): 0.7092
# Standard Error of Hedges' gs (Large N): 0.4549
# ...
